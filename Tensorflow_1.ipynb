# %%
import tensorflow as tf

# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import keras

# %%
from tensorflow.keras import layers

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('C:/Users/Pavel/Lessen_jypyter/train.csv')
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
dataset.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
dataset.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
dataset['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %%
test_dataset = pd.read_csv('C:/Users/Pavel/Lessen_jypyter/test.csv')
test_dataset
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
x = dataset.drop('price_range', axis = 1)
y = dataset['price_range']

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(20,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3610 - loss: 79.7040
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5090 - loss: 8.4741
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5765 - loss: 4.7023
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5905 - loss: 4.3850
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6180 - loss: 3.2642
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6250 - loss: 2.9056
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6000 - loss: 3.7482
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6495 - loss: 2.8031
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6055 - loss: 3.8830
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6335 - loss: 3.1883

# %%
test_loss, test_acc = model.evaluate(x ,y, verbose=2)
print('\nТестовая точность:', test_acc)
# Out:
# 63/63 - 1s - 12ms/step - accuracy: 0.6220 - loss: 3.1985
#
# Тестовая точность: 0.621999979019165

# %%
#---------- Модель №2

# %%
model_2 = keras.Sequential([
    keras.layers.Flatten(input_shape = (20,)),
    keras.layers.Dense(128,activation = 'relu'),
    keras.layers.Dense(4)
])

# %%
model_2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model_2.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4320 - loss: 79.0333
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4855 - loss: 10.1957
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5220 - loss: 5.8100
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5730 - loss: 5.1454
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5930 - loss: 4.9491
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6090 - loss: 3.8629
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6195 - loss: 3.5701
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6300 - loss: 3.2083
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6105 - loss: 4.4390
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6220 - loss: 4.4906

# %%
test_loss_2, test_acc_2 = model.evaluate(x ,y, verbose=2)
print('\nТестовая точность:', test_acc_2)
# Out:
# 63/63 - 0s - 4ms/step - accuracy: 0.6220 - loss: 3.1985
#
# Тестовая точность: 0.621999979019165

# %%
#---------- Модель №3

# %%
model_3 = keras.Sequential([
    keras.layers.Flatten(input_shape = (20,)),
    keras.layers.Dense(256,activation = 'relu'),
    keras.layers.Dense(6)
])

# %%
model_3.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model_3.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4290 - loss: 54.2056
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5410 - loss: 8.4614
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5700 - loss: 8.8625
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5995 - loss: 4.3992
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5700 - loss: 6.3387
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6040 - loss: 6.1458
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6120 - loss: 5.8309
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6205 - loss: 4.7554
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6365 - loss: 4.9347
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6510 - loss: 3.9413

# %%
test_loss_3, test_acc_3 = model.evaluate(x ,y, verbose=2)
print('\nТестовая точность:', test_acc_3)
# Out:
# 63/63 - 1s - 10ms/step - accuracy: 0.6775 - loss: 2.1156
#
# Тестовая точность: 0.6775000095367432

# %%
#---------- Модель №4

# %%
model_4 = keras.Sequential([
    keras.layers.Flatten(input_shape = (20,)),
    keras.layers.Dense(256,activation = 'relu'),
    keras.layers.Dense(4)
])

# %%
model_4.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model_4.fit(x, y, epochs=8)
# Out:
# Epoch 1/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4605 - loss: 21.7758
# Epoch 2/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5400 - loss: 5.9433
# Epoch 3/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6040 - loss: 4.0731
# Epoch 4/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5645 - loss: 5.3488
# Epoch 5/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6285 - loss: 3.0465
# Epoch 6/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6050 - loss: 3.9889
# Epoch 7/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6080 - loss: 4.0843
# Epoch 8/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6195 - loss: 3.8617

# %%
test_loss_4, test_acc_4 = model.evaluate(x ,y, verbose=2)
print('\nТестовая точность:', test_acc_4)
# Out:
# 63/63 - 0s - 5ms/step - accuracy: 0.6775 - loss: 2.1156
#
# Тестовая точность: 0.6775000095367432

# %%
#---------- Модель №5

# %%
model_5 = keras.Sequential([
    keras.layers.Flatten(input_shape = (20,)),
    keras.layers.Dense(1024,activation = 'relu'),
    keras.layers.Dense(8)
])

# %%
model_5.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model_5.fit(x, y, epochs=14)
# Out:
# Epoch 1/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6200 - loss: 6.4679
# Epoch 2/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6535 - loss: 5.1060
# Epoch 3/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6230 - loss: 7.4880
# Epoch 4/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6190 - loss: 6.5352
# Epoch 5/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 4.1653
# Epoch 6/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6165 - loss: 7.6328
# Epoch 7/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6630 - loss: 4.6079
# Epoch 8/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6720 - loss: 4.0260
# Epoch 9/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6480 - loss: 5.4212
# Epoch 10/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6465 - loss: 5.2275
# Epoch 11/14
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6220 - loss: 6.6528
# Epoch 12/14
# ...

# %%
test_loss_5, test_acc_5 = model.evaluate(x ,y, verbose=2)
print('\nТестовая точность:', test_acc_5)
# Out:
# 63/63 - 0s - 4ms/step - accuracy: 0.6775 - loss: 2.1156
#
# Тестовая точность: 0.6775000095367432

# %%
#----------

# %%
acc_tested = [test_acc, test_acc_2, test_acc_3, test_acc_4, test_acc_5]
acc_tested.sort()
print(f'Наивысшая полуенная точность:\n{acc_tested[-1]}')
# Out:
# Наивысшая полуенная точность:
# 0.6775000095367432
