# %%
from scipy.special import perm
from math import comb, perm

# %%
#1
n = 9
k = 3
n1 = 5
k1 = 3
ver = comb(n, k)
ver1 = comb(n1, k1)
sum =  ver1 / ver 
print(sum)
# Out:
# 0.11904761904761904

# %%
#2 
#n1 = 10
#n2 = 10
#n3 = 10
n1 = 10
n2 = 9
n3 = 8
n = 1000
sp = 10* 9 *8
nk = n - sp
sum = nk / 1000
print(sum)
# Out:
# 0.28
